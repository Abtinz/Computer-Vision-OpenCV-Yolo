# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# video reading from specified url

# %%
video_source = cv2.VideoCapture("./test.mp4")

while True:
    ret, frame = video_source.read()
    
    if not ret:
        print("Exiting ...")
        break
    cv2.imshow('video', frame)
    if cv2.waitKey(1) & 0xFF == 27:
        plt.imshow(frame[...,::-1])
        break

video_source.release()
cv2.destroyAllWindows()

# %%
#lets make it grayscale(we are changing the frame colors)
video_source = cv2.VideoCapture("./test.mp4")

while True:
    ret, frame = video_source.read()
    if not ret:
        break
    grayscale = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Gray video', grayscale)
    if cv2.waitKey(1) & 0xFF == 27:
        plt.imshow(grayscale , cmap = "gray")
        break

video_source.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Video Properties

# %%
video_source = cv2.VideoCapture('./test.mp4')
#capture.get + cap_prop ids will help us to check the video properties
print("width:", video_source.get(cv2.CAP_PROP_FRAME_WIDTH))
print("height:", video_source.get(cv2.CAP_PROP_FRAME_HEIGHT))
print("FPS:", video_source.get(cv2.CAP_PROP_FPS))
# Out:
# width: 480.0
# height: 270.0
# FPS: 30.0
