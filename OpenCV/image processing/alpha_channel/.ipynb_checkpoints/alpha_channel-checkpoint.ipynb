# %%
import cv2 as cv
import numpy as np

# %% [markdown]
# cv.IMREAD_UNCHANGED
#
# will provide a code for reading  png images with fourth channel

# %%
image = cv.imread("./transparency.png", cv.IMREAD_UNCHANGED)
image.shape
# Out:
# (600, 800, 4)

# %%
cv.imshow("transparency",image)
cv.waitKey()
cv.destroyAllWindows()

# %% [markdown]
# # RGB Channels

# %%
bgr_image = image[:,:,0:3]
rgb_image = cv.cvtColor(bgr_image ,cv.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.imshow(rgb_image)
plt.title("RGB IMAGE")
# Out:
# Text(0.5, 1.0, 'RGB IMAGE')

# %% [markdown]
# image[:,:,-1] -> this is our alpha trnsparrecy channel
#
# -1 index is the last index sign in numpy

# %%
alpha_channel = image[:,:,-1]

# %%
plt.imshow(alpha_channel,cmap = "gray")
plt.title("alpha channel IMAGE")
# Out:
# Text(0.5, 1.0, 'alpha channel IMAGE')
