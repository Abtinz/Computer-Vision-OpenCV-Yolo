# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('gradient.jpg')

binary_image = np.copy(image)
binary_image[binary_image <  127] = 0
binary_image[binary_image >= 127] = 255    

plt.figure(figsize=[10,10])
plt.subplot(121);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(122);plt.imshow(binary_image, cmap='gray');plt.title("how legends calculate binary images");

# %% [markdown]
# ## OpenCV Threshold Functions

# %% [markdown]
# Thresholding and inverted Thresholding

# %%
_ ,binary = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
_ ,binary_inverted = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=[10,10])
plt.subplot(231);plt.imshow(binary, cmap='gray');plt.title("Threshold - Binary");
plt.subplot(232);plt.imshow(binary_inverted, cmap='gray');plt.title("Threshold - Binary Inverse")
# Out:
# Text(0.5, 1.0, 'Threshold - Binary Inverse')

# %% [markdown]
# Truncate

# %%
_ ,truncate = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)
plt.imshow(truncate, cmap='gray');plt.title("truncate");

# %% [markdown]
# Threshold to Zero

# %%
_ ,threshold_zero = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO)

_ ,threshold_zero_inverted = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO_INV)
    
plt.figure(figsize=[10,10])

plt.subplot(221);plt.imshow(threshold_zero, cmap='gray');plt.title("threshold zero");
plt.subplot(222);plt.imshow(threshold_zero_inverted, cmap='gray');plt.title("threshold zero inverted");

# %%
image = cv2.imread('plate.jpg',0)

_ ,binary_threshold = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)


_ ,trunc = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)

    
plt.figure(figsize=[10,10])
plt.subplot(231);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(232);plt.imshow(binary_threshold, cmap='gray');plt.title("Threshold - Binary");
plt.subplot(233);plt.imshow(trunc, cmap='gray');plt.title("trunc");
