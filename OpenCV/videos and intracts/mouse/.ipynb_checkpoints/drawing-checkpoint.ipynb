# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt

# %%
drawing = False 

#this function will handle mouse click event by callback process
def brush(event,x,y,flags,param):
    global drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.circle(image,(x,y),5,(250,100,200),-1)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
            
image = np.zeros((512,512,3), "uint8")
cv2.namedWindow('image')
cv2.setMouseCallback('image',brush)

while True:
    cv2.imshow('image',image)
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
plt.imshow(image[...,::-1])

# %% [markdown]
# # The Problem of Distance Between Points

# %%
drawing = False 

#this function will handle mouse click event by callback process
def brush(event,x,y,flags,param):
    global drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.circle(image,(x,y),5,(250,100,200),-1)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
            
image = np.zeros((512,512,3), "uint8")
cv2.namedWindow('image')
cv2.setMouseCallback('image',brush)

while True:
    cv2.imshow('image',image)
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
plt.imshow(image[...,::-1])

# %% [markdown]
# Take look at this picture, when you move your mouse quickly, you can see the problem of point distances
#
# here is the main solution

# %%
image = np.zeros((512,512,3))
drawing = False

#the key solution of this problem is defining coordinates of current points for starting the line drawing from there!
ix , iy = 0 , 0

def draw(event,x,y,flags,params):
    global ix,iy,drawing
    
    if event==cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix = x
        iy = y
    if event==cv2.EVENT_MOUSEMOVE:
        if drawing==True:
            
            cv2.line(image,pt1=(ix,iy),pt2=(x,y),color=(255,255,255),thickness=3)
            ix = x
            iy = y
    if event==cv2.EVENT_LBUTTONUP:
        drawing = False


cv2.namedWindow("Window")
cv2.setMouseCallback("Window",draw)

while True:

    cv2.imshow("Window",image)

    if cv2.waitKey(1) & 0xFF ==27:
        break

cv2.destroyAllWindows()
plt.imshow(image[...,::-1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
