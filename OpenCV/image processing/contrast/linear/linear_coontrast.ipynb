# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread('./taken.jpg')
plt.imshow(image[...,::-1])

# %%
alpha = float(input('alpha(0.1:3.0): '))
beta = int(input('beta(0:100): '))
# Out:
# alpha(0.1:3.0): 2
# beta(0:100): 40

# %%
alpha

# %%
new_image = cv.convertScaleAbs(image, alpha=alpha, beta=beta)

            
plt.figure(figsize=[15,5])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("Original");
plt.subplot(122);plt.imshow(new_image[...,::-1]);plt.title("Output");
# Out:
# * Enter the alpha value [0.1-3.0]: 0.2
# * Enter the beta value [0-100]: 40
